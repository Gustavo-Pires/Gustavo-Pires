# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavo-Pires/Gustavo-Pires/blob/main/Python_e_mercado_Financeiro_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python e mercado Financeiro**
# ---

# %% [markdown]
# ## 1.1 Princípios de Programação
#
# No console é onde os programas podem ser executados, as instalações das bibliotecas são feitas com o comando pip install ou são realizadas programações simples, como operações, leituras de arquivos, impressões em arquivos ou gráficos simples.
#
# Na utilização do Console, números com colchetes indicam quantas linhas de comando já foram utilizadas, como In [1]:, In [2]:, In [3]: etc. Quando o Console ficar com muitas linhas de programação, você pode limpá-lo escrevendo a palavra “clear” em qualquer linha. Outras vezes, muitas programações erradas podem travar o Python.

# %% [markdown]
# ## 1.2 Operacoes simples no console
# **Operações** simples e rápidas podem ser realizadas na área Console, janela inferior à direita na Figura 1.2. Somas, subtrações, divisões e chamadas de funções pré-programadas no Python podem rodar independentemente de qualquer algoritmo ou progra
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Operações matemáticas podem ser realizadas dentro do comando de impressão **PRINT( )**, sem a necessidade da criação de novas variáveis. Pode-se ter, então, para algumas operações básicas os resultados diretamente no **Console**
#
#
# ```
# In  [1]:print(11*9)
# Out [1]: 99
# ```
#
#
# Funções mais elaboradas como exponencial ou logaritmo, em matemática, necessi- tam de importação do módulo para seu funcionamento. Usar a biblioteca *Math*

# %% [markdown]
# ## 1.3 Listas no Console

# %% [markdown]
# Lista, no Python, é uma sequência ordenada em que os elementos são sempre asso- ciados a um índice. Apesar de lembrar vetores ou matrizes de outras linguagens de programação, uma lista é mais simples e de fácil manipulação com dados numéricos ou strings (letras). Como será visto em outras partes do texto, o Python também possui estruturas como vetores ou matrizes, mas seu uso é mais sofisticado do que uma lista.
# O uso de listas no Console é bem simples e intuitivo

# %%
dados=[10,5,1,1,2,2,3,5,10,2,2,1,3,4,4]
print("O Primeiro elemento da lista é " + str(dados[0]))
print("O ultimo elemento da lista é " + str(dados[-1]))
# Out:
# O Primeiro elemento da lista é 10
# O ultimo elemento da lista é 4

# %% [markdown]
# *Bibliotecas uteis Python*
#
# *   Numpy-( Numerical python)
# *   Scipy-(scientific python) biblioteca contem  funções de álgebra linear, analise de Fourier, estatística e etc.
# *   Pandas-(python data analysis library)
# *   Xlrd- para abrir dados salvos em arquivos do Excel
# *   Matplotlib-( plotinglibary) Faz qualquer tipo de gráfico
# *   Openpyxl-(open python) para abrir dados salvos em arquivos do Excel
#
# A chamada ou importação de uma biblioteca do Python pode ser simplificada por sua renomeação com um “apelido” que denote a respectiva função. Por exemplo, a biblioteca de matemática math pode ser simplificada em sua chamada usando na frente de seu nome a denominação “as” seguida do apelido.

# %%
import xlrd 
import numpy as ny 
import matplotlib.pyplot as fig 
import openpyxl as op
import statistics as st #usada para calcular o desvio padrao
import math as mt

# %% [markdown]
# Três bibliotecas tornam-se essenciais no desenvolvimento de cálculos mais avan- çados e colaboram com a ampliação do espectro de análises já proporcionada pela biblioteca de estatística.
# A biblioteca *numpy* (numerical Python) é fundamental na computação científica em Python, aumentando as funcionalidades para o uso de array (vetores e matrizes) e auxiliando em muitas atividades. As bibliotecas *scipy *(scientific Python), *pandas* (Python data analysis library) e *matplotlib* (plotting library) completam o pacote essen- cial para gráficos, análises de tabelas, como a tabela dinâmica no Excel (pivot table) chamada DataFrame, e algoritmos para cálculos com vetores e matrizes. Essas quatro bibliotecas, mais matemática e estatística vistas anteriormente, fecham o pacote da maioria das atividades que todo programador ou analista precisa para entender uma série de dados.

# %% [markdown]
# ![Tabela1.png](data:image/png;base64,...)

# %%
a=[1, 21, 3, 11, 5, 15, 7, 8, 9, 10]
b=[10, 12, 14, 16, 20, 4, 33]
a.append(7)
a.count(10)
a.extend(b)


print(a)

a.index(12)
a.insert(14, a.index(12))
a.remove(33)
print(a)

a.sort()
print(a)

a.reverse()
print(a)

a.clear()
print(a)
# Out:
# [1, 21, 3, 11, 5, 15, 7, 8, 9, 10, 7, 10, 12, 14, 16, 20, 4, 33]
# [1, 21, 3, 11, 5, 15, 7, 8, 9, 10, 7, 10, 12, 14, 12, 16, 20, 4]
# [1, 3, 4, 5, 7, 7, 8, 9, 10, 10, 11, 12, 12, 14, 15, 16, 20, 21]
# [21, 20, 16, 15, 14, 12, 12, 11, 10, 10, 9, 8, 7, 7, 5, 4, 3, 1]
# []

# %% [markdown]
# ##1.4

# %% [markdown]
# ##1.5

# %% [markdown]
# ##1.6

# %%
import matplotlib.pyplot as fig
import numpy as ny

x=ny.arange(1,20)#criei um vetor com 20 pontos
y=3*x-3 #vetor y com base na equacao fornecida 

#Formatacoes
fig.title("Grafico da Funcao")# titulo do grafico
fig.xlabel("eixo x")# nome do eixo x
fig.ylabel("eixo y") 

fig.plot(x,y) # faz o grafico colocando o vetor x no horizontal e y no vertical
fig.plot(x,y) #
fig.savefig("grafico 1_6.png") # salva o grafico em um arquivo png

fig.show() # mostra o grafico na tela

# %%
 
import matplotlib.pyplot as fig #importa a biblioteca matplotlib.pyplot
import numpy as ny #importa a biblioteca numpy
import openpyxl
import xlrd 

x=ny.arange(1,20) #cria um vetor com 20 pontos
y=3*x-3 #vetor y com base na equacao fornecida
fig.plot(x,y); fig.title("Reta"); fig.xlabel("Eixo x"); fig.ylabel("Eixo y"); fig.savefig("grafico_1.png"); #faz o grafico colocando o vetor x no horizontal e y no vertical

 
f=open('dados.txt', 'w') #abre o arquivo dados.txt para escrita
f.write("%d %d %d\n'" % (x[0], x[1], x[2])) #escreve no arquivo dados.txt os valores do vetor x
f.close #fecha o arquivo dados.txt

arq = openpyxl.load_workbook('amostras.xlxs') #abre o arquivo amostras.xlxs
plan = arq['dados'] #abre a planilha dados
dados_planilha = plan['b2'].value #pega o valor da celula b2
print(dados_planilha) #imprime o valor da celula b2

e = #definir variavel 
f = #definir variavel 
g = #definir variavel
h = #definir variavel 
i = #definir variavel

fem_apr = [10, 9, 8, 9, 9 ]  #definir lista                            


x=ny.arange(1,6) #cria um vetor com 6 pontos
y=4*x-2 #vetor y com base na equacao fornecida
fig.plot(x,y); fig.title("Reta"); fig.xlabel("Eixo x"); fig.ylabel("Eixo y"); fig.savefig("grafico_1.png"); #faz o grafico colocando o vetor x no horizontal e y no vertical

fig.plot(x,y); fig.title("Reta"); fig.xlabel("Eixo x"); fig.ylabel("Eixo y"); fig.savefig("grafico_1.png"); #faz o grafico colocando o vetor x no horizontal e y no vertical
# Out:
#   File "<ipython-input-3-e9920c4b373f>", line 20
#     e = #definir variavel
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 1.7 Arquivos de tipo de texto no console
# **No Console do Python, é possível importar e exportar qualquer tipo de dados para todos os formatos conhecidos**. Como exemplo, os arquivos do tipo texto são expor- tados e importados com a técnica bastante conhecida há décadas como *open e write*.

# %% [markdown]
# `Variável = open(‘nome do arquivo’, ‘tipo de procedimento’)`

# %% [markdown]
# Depois do comando open, o **primeiro** elemento do parêntese é **o nome do arquivo** que **se deseja criar ou ler do diretório.** **O segundo elemento deve ser completado com w** para imprimir um resultado no arquivo (write) ou **r para ler um conjunto de dados já existente** (read). Vamos supor que desejamos criar um arquivo de texto com nome dad.txt e que nele desejamos exportar a lista x = [3,2,1]. Os comandos de linha são os seguintes.

# %%
x=[3, 2, 1]
f=open('teste.txt', 'w')
f.write('%d %d %d\n'% (x[0], x[1], x[2]))
# Out:
# 6

# %% [markdown]
# Na ordem das linhas, primeiro se cria a lista, depois abre-se o programa dad.txt com operador w, indicando que o arquivo vai ser usado para impressão. A seguir, tem-se o comando write. O nome da variável que se criou para abrir o arquivo foi f, por isso o comando recebe o nome da variável com ponto decimal e comando de impressão write.

# %% [markdown]
# A formatação do arquivo precisa ser elemento a elemento, respeitando a tabela de impressão para arquivos tipo texto. Como são três elementos na lista, cada um deve ser especificado. Utiliza-se sempre o símbolo % com aspas simples para indicar a forma- tação do número. Para o caso de número inteiro, o formato é %d. O símbolo \n indica que, após o último elemento, o programa muda de linha, permitindo em uma próxima impressão a utilização da linha de baixo. O símbolo % após os comandos dentro das aspas simples indica que os dados vão ser fornecidos a seguir. Como temos mais de um elemento na lista, deve-se usar ( ) e indicar cada elemento a ser impresso.

# %% [markdown]
# Por fim, é obrigatório o fechamento do arquivo usando o comando close com o nome da variável em ponto decimal. No caso do exemplo, f.close( ) fecha o arquivo, e os parênteses do comando close devem estar vazios, como visto anteriormente.
# O resultado no diretório vai ser o nome aparecendo com a data da criação do arquivo, o tipo de documento (texto nesse caso) e o tamanho em bytes.

# %%
f=open('teste.txt', 'r')
f.write('%d %d %d\n'% (x[0], x[1], x[2]))
y=f.read()

print(y)
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-00491ca7ed13> in <module>
# ----> 1 f=open('teste.txt', 'r')
#       2 f.write('%d %d %d\n'% (x[0], x[1], x[2]))
#       3 y=f.read()
#       4
#       5 print(y)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'teste.txt'

# %% [markdown]
# Novamente o arquivo é aberto com open, e agora utiliza-se read para ler o arquivo. Nesse caso, uma variável precisa receber os números do arquivo, que nesse exemplo cha- mamos de y. Ao imprimir y, recuperamos a lista original que estava em x, mas que agora foi importada do arquivo dad.txt. Finalmente, deve-se fechar o arquivo usando close.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##1.8 Arquivos excel no console

# %% [markdown]
# ## 4.6 Grafico Tridimensonal

# %%
from mpl_toolkits import mplot3d 
import matplotlib.pyplot as fig 
import numpy as ny 


ax=fig.axes(projection='3d')

z=ny.linspace(0, 15, 1000)
x=ny.sin(z)
y=ny.cos(z)
ax.plot3D(x, y, z, 'red')

dadZ=15*ny.random.random(100)
dadX=ny.sin(dadZ)+0.2*ny.random.randn(100)
dadY=ny.cos(dadZ)+0.2*ny.random.randn(100)
ax.scatter3D(dadX, dadY, dadZ, c=dadZ, cmap='Greys');
ax.set_xlabel('eixo x')
ax.set_ylabel('eixo y')
ax.set_zlabel('eixo x')
# Out:
# Text(0.5, 0, 'eixo x')

# %% [markdown]
# #1 2 3
